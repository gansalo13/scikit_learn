# %% [markdown]
# <a href="https://colab.research.google.com/github/gansalo13/scikit_learn/blob/main/scikit_exer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# http://seaborn.pydata.org/generated/seaborn.jointplot.html

# %%
import numpy as np # Numpy provides fast mathematical function processing 
import pandas as pd # pandas is used for easy indexing and data collection tools 
import matplotlib as mpl # data visualisation libraries 
import matplotlib.pyplot as plt #High Level Data Visualization library
import seaborn as sns #import library to create a heatmap
# %matplotlib inline

# %% [markdown]
# **. Write a Python program to load the iris data from a given csv file into a dataframe and print the shape of the data, type of the data and first 3 rows**

# %%
iris_data = pd.read_csv('https://raw.githubusercontent.com/gansalo13/scikit_learn/main/Iris.csv')
iris_data.shape # this provides info about the rows and columns
# Out:
# (150, 6)

# %%
iris_data.dtypes # this returns the data type of all the objects in the data set
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
iris_data.head(3) #Returns the first 3 rows of our data
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %% [markdown]
# **2. Write a Python program using Scikit-learn to print the keys, number of rows-columns, feature names and the description of the Iris data**

# %%
iris_data.keys() # This returns the indexing for the columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris_data.shape  # this provides info about the rows and columns
# Out:
# (150, 6)

# %%
iris_data.describe() #overview of the std, mean , mode
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# **3. Write a Python program to get the number of observations, missing values and nan values**

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_data.isnull().values.any() # False means No there are no any Null or NAN values
# Out:
# False

# %% [markdown]
# **4. Write a Python program to create a 2-D array with ones on the diagonal and zeros elsewhere. Now convert the NumPy array to a SciPy sparse matrix in CSR format**

# %%
x = np.eye(2) # The eye tool returns a 2-D array with  1’s as the diagonal and  0’s elsewhere

# %%
from scipy import sparse 
sparse_matrix = sparse.csr_matrix(x)
print(sparse_matrix)
# Out:
#   (0, 0)	1.0
#   (1, 1)	1.0

# %% [markdown]
# **5. Write a Python program to view basic statistical details like percentile, mean, std etc. of iris data.**

# %%
iris_data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# **6. Write a Python program to get observations of each species (setosa, versicolor, virginica) from iris data.**

# %%
iris_data['Species'].value_counts() # this counts the number of species
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %% [markdown]
# **7. Write a Python program to drop Id column from a given Dataframe and print the modified part. Call iris.csv to create the Dataframe**

# %%
iris_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
new_data = iris_data.drop('Id',axis=1) # .drop will take off the row or columns while still keeping the old data

# %%
new_data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **8. Write a Python program to access first four cells from a given Dataframe using the index and column labels. Call iris.csv to create the Dataframe**

# %%
x = iris_data.iloc[:, [1, 2, 3, 4]].values
x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %% [markdown]
# **Visualization - Iris flower data set**

# %% [markdown]
# **1. Write a Python program to create a plot to get a general Statistics of Iris data**

# %%
import matplotlib.pyplot as plt # data visualisation libraries 
iris_data.describe().plot(kind = "area",fontsize=16, figsize = (15,8), table = True, colormap="Accent")
plt.xlabel('Statistics',) # labeling the independent variable 
plt.ylabel('Value') # labeling the dependent variable 
plt.title("General Statistics of Iris Dataset") # map title
#plt.show()
# Out:
# Text(0.5, 1.0, 'General Statistics of Iris Dataset')

# %% [markdown]
# **2. Write a Python program to create a Bar plot to get the frequency of the three species of the Iris data**

# %%
import seaborn as sns #import library to create a heatmap
import matplotlib.pyplot as plt # data visualisation libraries

ax=plt.subplots(1,1,figsize=(10,8)) # subplots method provides a way to plot multiple plots on a single figure.
sns.countplot('Species',data=iris_data) #seaborn.countplot() method is used to Show the counts of observations in each categorical bin using bars.
plt.title("Iris Species Count")
plt.show()

# %% [markdown]
# **3. Write a Python program to create a Pie plot to get the frequency of the three species of the Iris data**

# %%
ax=plt.subplots(1,1,figsize=(10,8))
iris_data['Species'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1f%%',shadow=True,figsize=(10,8))
plt.title("Iris Species %")
plt.show()

# %% [markdown]
# **4. Write a Python program to create a graph to find relationship between the sepal length and width**

# %%
iris_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# iris = pd.read_csv("iris.csv")
fig = iris_data[iris_data.Species=='Iris-setosa'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='orange', label='Setosa')
iris_data[iris_data.Species=='Iris-versicolor'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='blue', label='versicolor',ax=fig)
iris_data[iris_data.Species=='Iris-virginica'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='green', label='virginica', ax=fig)
fig.set_xlabel("Sepal Length")
fig.set_ylabel("Sepal Width")
fig.set_title("Sepal Length VS Width")
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.show()

# %% [markdown]
# # 5*.*Write a Python program to create a graph to find relationship between the petal length and width.**

# %%
#iris = pd.read_csv("iris.csv")
fig = iris_data[iris_data.Species=='Iris-setosa'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='orange', label='Setosa')
iris_data[iris_data.Species=='Iris-versicolor'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='blue', label='versicolor',ax=fig)
iris_data[iris_data.Species=='Iris-virginica'].plot.scatter(x='PetalLengthCm',y='PetalWidthCm',color='green', label='virginica', ax=fig)
fig.set_xlabel("Petal Length")
fig.set_ylabel("Petal Width")
fig.set_title(" Petal Length VS Width")
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.show()

# %% [markdown]
# **6. Write a Python program to create a graph to see how the length and width of SepalLength, SepalWidth, PetalLength, PetalWidth are distributed.**

# %%
new_data.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf() # create a figure object
fig.set_size_inches(12,12) #set size in inches 
plt.show()

# %% [markdown]
# **7. Write a Python program to create a joinplot to describe individual distributions on the same plot between Sepal length and Sepal width**

# %%
# Jointplot is seaborn library specific and can be used to quickly visualize and analyze the relationship between two variables and describe their individual distributions on the same plot.
fig=sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', data=iris_data, color='blue') #Draw a plot of two variables with bivariate and univariate graphs.
plt.show()

# %% [markdown]
# **8. Write a Python program to create a joinplot using "hexbin" to describe individual distributions on the same plot between Sepal length and Sepal width**

# %%
# Jointplot is seaborn library specific and can be used to quickly visualize and analyze the relationship between two variables and describe their individual distributions on the same plot.
fig=sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', kind="hex", color="red", data=iris_data) #setting kind="hex" will use matplotlib.axes.Axes.hexbin() to compute a bivariate histogram using hexagonal bins 
plt.show()

# %% [markdown]
# **9. Write a Python program to create a joinplot using "kde" to describe individual distributions on the same plot between Sepal length and Sepal width.**

# %%
# Jointplot is seaborn library specific and can be used to quickly visualize and analyze the relationship between two variables and describe their individual distributions on the same plot.
fig=sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', kind="kde", color='cyan', data=iris_data) #Setting kind="kde" will draw both bivariate and univariate KDEs 
plt.show()

# %% [markdown]
# **10. Write a Python program to create a joinplot and add regression and kernel density fits using "reg" to describe individual distributions on the same plot between Sepal length and Sepal width**

# %%
# Jointplot is seaborn library specific and can be used to quickly visualize and analyze the relationship between two variables and describe their individual distributions on the same plot.
fig=sns.jointplot(x='SepalLengthCm', y='SepalWidthCm', kind="reg", color='red', data=iris_data) # Set kind="reg" to add a linear regression fit (using regplot()) and univariate KDE curves:
plt.show()

# %% [markdown]
# **11. Write a Python program to draw a scatterplot, then add a joint density estimate to describe individual distributions on the same plot between Sepal length and Sepal width**

# %%
# Use JointGrid parameters to control the size and layout of the figure:
sns.jointplot("SepalLengthCm", "SepalWidthCm", data=iris_data, color="b").plot_joint(sns.kdeplot, zorder=0, n_levels=6) # To add more layers onto the plot, use the methods on the JointGrid object that jointplot() returns
plt.show()

# %% [markdown]
# 12. Write a Python program to create a joinplot using "kde" to describe individual distributions on the same plot between Sepal length and Sepal width and use '+' sign as marker.
#
# Note:
# The kernel density estimation (kde) procedure visualize a bivariate distribution. In seaborn, this kind of plot is shown with a contour plot and is available as a style in jointplot()

# %%
# Jointplot is seaborn library specific and can be used to quickly visualize and analyze the relationship between two variables and describe their individual distributions on the same plot.
g = sns.jointplot(x="SepalLengthCm", y="SepalWidthCm", data=iris_data, kind="kde", color="m")
g.plot_joint(plt.scatter, c="w", s=40, linewidth=1, marker="+") 
g.ax_joint.collections[0].set_alpha(0)
g.set_axis_labels("$SepalLength(Cm)$", "$SepalWidth(Cm)$") 
plt.show()

# %% [markdown]
# **13. Write a Python program to create a pairplot of the iris data set and check which flower species seems to be the most separable**

# %%
#sns.pairplot(data=iris_data,kind='scatter')
''' A “pairs plot” is also known as a scatterplot, in which one variable in the same data row is matched with another variable's value,
 like this: Pairs plots are just elaborations on this, showing all variables paired with all the other variables.'''

sns.pairplot(iris_data,hue='Species');

# %% [markdown]
# **14. Write a Python program using seaborn to Create a kde (Kernel Density Estimate ) plot of sepal_length versus sepal width for setosa species of flower**

# %%
# g = sns.jointplot(x="SepalLengthCm", y="SepalWidthCm", data=iris_data, kind="kde", color="m")


sub=iris_data[iris_data['Species']=='Iris-setosa'] #pulls the column out of the species iris-setosa
# sns.kdeplot(data=sub[['SepalLengthCm','SepalWidthCm']], shade=True, shade_lowest=False)
x = sub['SepalLengthCm'] #calls the function sub which takes the column out of data
y = sub['SepalWidthCm']
sns.kdeplot(x,y,shade=True, shade_lowest=False)
plt.title('Iris-setosa')
plt.xlabel('Sepal Length cm')
plt.ylabel('Sepal Width cm')
plt.show()

# %% [markdown]
# **15. Write a Python program using seaborn to Create a kde (Kernel Density Estimate ) plot of petal_length versus petal width for setosa species of flower**

# %%
x = sub['PetalLengthCm'] #calls the function sub which takes the column out of data
y = sub['PetalWidthCm']
sns.kdeplot(x,y,shade=True)



plt.title('Iris-setosa')
plt.xlabel('Petal Length Cm')
plt.ylabel('Petal Width Cm')
plt.show()

# %% [markdown]
# **16. Write a Python program using seaborn to Create a kde (Kernel Density Estimate ) plot of petal_length versus petal width for setosa species of flower**

# %%
# sns.kdeplot(data=sub[['PetalLengthCm','PetalWidthCm']],cmap="plasma", shade=True, shade_lowest=False)

x = sub['PetalLengthCm'] #calls the function sub which takes the column out of data
y = sub['PetalWidthCm']
sns.kdeplot(x,y,shade=True, shade_lowest=False)
plt.title('Iris-setosa')
plt.xlabel('Petal Length Cm')
plt.ylabel('Petal Width Cm')
plt.show()

# %% [markdown]
# **17. Write a Python program to find the correlation between variables of iris data. Also create a hitmap using Seaborn to present their relations**

# %%
X = iris_data.iloc[:, 0:4] 
f, ax = plt.subplots(figsize=(10, 8))
corr = X.corr()
print(corr)
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), 
          cmap=sns.diverging_palette(220, 10, as_cmap=True),square=True, ax=ax, linewidths=.5)
plt.show()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000

# %% [markdown]
# 18. Write a Python program to create a box plot (or box-and-whisker plot) which shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable of iris dataset. Use seaborn

# %%
box_data = iris_data #variable representing the data array
box_target = iris_data.Species #variable representing the labels array
sns.boxplot(data = box_data,width=0.5,fliersize=5)
sns.set(rc={'figure.figsize':(2,15)})
